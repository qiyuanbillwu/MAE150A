# %%
using FluidDynTools

# %%
using Plots

# %%
using SpecialFunctions

# %%
u(y,nu,t) = 1-erf(y/(2*sqrt(nu*t)))
# Out:
# u (generic function with 2 methods)

# %%
nu = KinematicViscosity(1)
# Out:
# KinematicViscosity = 1.0 m^2 s^-1

# %%
t1 = 0.1u"s"
t2 = 1u"s"
t3 = 10u"s"
# Out:
# 10 s

# %%
y1 = range(0u"m",2u"m",length=101)
y2 = range(0u"m",10u"m",length=101)
y3 = range(0u"m",20u"m",length=101)
# Out:
# (0.0:0.2:20.0) m

# %%
v1 = u.(y1,nu,t1)
v2 = u.(y2,nu,t2)
v3 = u.(y3,nu,t3)
# Out:
# 101-element Vector{Float64}:
#  1.0
#  0.9643294082703201
#  0.9287300745648026
#  0.8932728301422118
#  0.8580276569875211
#  0.8230632737581215
#  0.788446734264471
#  0.7542430423910373
#  0.7205147871362553
#  0.6873218011739947
#  0.654720846018577
#  0.6227653265162957
#  0.5915050369949165
#  ⋮
#  6.885702262660054e-5
#  5.699411623327766e-5
#  4.708508681605661e-5
#  3.8824656203861885e-5
#  3.195229760633023e-5
#  2.6246182954436925e-5
#  2.1517864378095553e-5
#  1.760761440328107e-5
#  1.4380355041199167e-5
#  1.1722111469492091e-5
#  9.536931399933835e-6
#  7.744216431015971e-6

# %%
plot(v1,y1,xlim=(0,Inf),ylim=(0,Inf),xlabel=L"u(y)",ylabel=L"y")

# %%
plot(v2,y2,xlim=(0,Inf),ylim=(0,Inf),xlabel=L"u(y)",ylabel=L"y")

# %%
plot(v3,y3,xlim=(0,Inf),ylim=(0,Inf),xlabel=L"u(y)",ylabel=L"y")
