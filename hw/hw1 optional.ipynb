# %%
using FluidDynTools
using Plots

# %%
p0 = Pressure(1u"atm")
# Out:
# Pressure = 101325.0 Pa

# %%
ρ = Density(Air)
# Out:
# Density = 1.225225682761773 kg m^-3

# %%
R = 100u"m"
# Out:
# 100 m

# %%
Ω = 1u"rad/s"
# Out:
# 1 rad s^-1

# %%
pre1(r1) = p0 + 0.5*ρ*Ω^2*r1^2-ρ*Ω^2*R^2
pre2(r2) = p0 - ρ*Ω^2*R^4/(2*r2^2)
# Out:
# pre2 (generic function with 1 method)

# %%
r1 = range(0u"m",100u"m",length=1001)
r2 = range(100u"m",200u"m",length=1001)
# Out:
# (100.0:0.1:200.0) m

# %%
pre1s = pre1.(r1)
pre2s = pre2.(r2)
# Out:
# 1001-element Vector{Unitful.Quantity{Float64, 𝐌 𝐋^-1 𝐓^-2, Unitful.FreeUnits{(kg, m^-1, s^-2), 𝐌 𝐋^-1 𝐓^-2, nothing}}}:
#  95198.87158619113 kg m^-1 s^-2
#  95211.10548910743 kg m^-1 s^-2
#   95223.3027818526 kg m^-1 s^-2
#   95235.4636103565 kg m^-1 s^-2
#  95247.58811982264 kg m^-1 s^-2
#  95259.67645473244 kg m^-1 s^-2
#  95271.72875884963 kg m^-1 s^-2
#  95283.74517522441 kg m^-1 s^-2
#   95295.7258461978 kg m^-1 s^-2
#  95307.67091340585 kg m^-1 s^-2
#  95319.58051778369 kg m^-1 s^-2
#  95331.45479956985 kg m^-1 s^-2
#  95343.29389831034 kg m^-1 s^-2
#                               ⋮
#  99776.48103058302 kg m^-1 s^-2
#  99778.03694002453 kg m^-1 s^-2
#  99779.59050564081 kg m^-1 s^-2
#  99781.14173213717 kg m^-1 s^-2
#  99782.69062420708 kg m^-1 s^-2
#   99784.2371865323 kg m^-1 s^-2
#   99785.7814237828 kg m^-1 s^-2
#  99787.32334061689 kg m^-1 s^-2
#   99788.8629416812 kg m^-1 s^-2
#  99790.40023161078 kg m^-1 s^-2
#    99791.935215029 kg m^-1 s^-2
#  99793.46789654778 kg m^-1 s^-2

# %%
plot(r1,pre1s,xlim=(0,Inf),ylim=(8.5e4,Inf),xlabel=L"r",ylabel=L"pressure", label="r<=R", legend=true)
plot!(r2,pre2s,xlim=(0,Inf),ylim=(8.5e4,Inf),xlabel=L"r",ylabel=L"pressure", label="r>=R", legend=true)
vline!([100], label="R=100m", color="red", line=:dash)
